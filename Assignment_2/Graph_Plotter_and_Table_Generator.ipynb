# %%
import matplotlib.pyplot as plt
import json

# %%
# !g++ mergesort.cpp -o mergesort

# %%
# !mergesort.exe

# %%
x = json.load(open('output.json'))
size_array = []
time_array = []
for i in x['data_1']:
    size_array.append(len(i['input']))
    output = i['output']
    time_array.append((i['time']))

# %%
plt.plot(size_array, time_array)
plt.xlabel('Size of input')
plt.ylabel('Time taken')
plt.savefig('plot_1.png')
plt.show()

# %%
size_array = []
time_array = []
for i in x['data_2']:
    size_array.append(len(i['input']))
    output = i['output']
    time_array.append((i['time']))
plt.plot(size_array, time_array)
plt.xlabel('Size of input')
plt.ylabel('Time taken')
plt.savefig('plot_2.png')
plt.show()

# %%
size_array = []
time_array = []
for i in x['data_3']:
    size_array.append(len(i['input']))
    output = i['output']
    time_array.append((i['time']))
plt.plot(size_array, time_array)
plt.xlabel('Size of input')
plt.ylabel('Time taken')
plt.savefig('plot_3.png')
plt.show()

# %%
size_array = []
time_array = []
for i in x['data_4']:
    size_array.append(len(i['input']))
    output = i['output']
    time_array.append((i['time']))
plt.plot(size_array, time_array)
plt.xlabel('Size of input')
plt.ylabel('Time taken')
plt.savefig('plot_4.png')
plt.show()

# %%
size_array = []
time_array = []
for i in x['data_5']:
    size_array.append(len(i['input']))
    output = i['output']
    time_array.append((i['time']))
plt.plot(size_array, time_array)
plt.xlabel('Size of input')
plt.ylabel('Time taken')
plt.savefig('plot_5.png')
plt.show()

# %%
import docx

# %%
doc = docx.Document()
table = doc.add_table(rows=1, cols=3)
table.style = 'Table Grid'
row = table.rows[0].cells
row[0].text = 'Input'
row[1].text = 'Output'
row[2].text = 'Time taken'

for i in x['data_1']:
    row = table.add_row().cells
    row[0].text = str((i['input']))
    row[1].text = str(i['output'])
    row[2].text = str(i['time'])

doc.save('output_1.docx')

# %%
doc = docx.Document()
table = doc.add_table(rows=1, cols=3)
table.style = 'Table Grid'
row = table.rows[0].cells
row[0].text = 'Input'
row[1].text = 'Output'
row[2].text = 'Time taken'

for i in x['data_2']:
    row = table.add_row().cells
    row[0].text = str((i['input']))
    row[1].text = str(i['output'])
    row[2].text = str(i['time'])

doc.save('output_2.docx')

# %%
doc = docx.Document()
table = doc.add_table(rows=1, cols=3)
table.style = 'Table Grid'
row = table.rows[0].cells
row[0].text = 'Input'
row[1].text = 'Output'
row[2].text = 'Time taken'

for i in x['data_3']:
    row = table.add_row().cells
    row[0].text = str((i['input']))
    row[1].text = str(i['output'])
    row[2].text = str(i['time'])

doc.save('output_3.docx')

# %%
doc = docx.Document()
table = doc.add_table(rows=1, cols=3)
table.style = 'Table Grid'
row = table.rows[0].cells
row[0].text = 'Input'
row[1].text = 'Output'
row[2].text = 'Time taken'

for i in x['data_4']:
    row = table.add_row().cells
    row[0].text = str((i['input']))
    row[1].text = str(i['output'])
    row[2].text = str(i['time'])

doc.save('output_4.docx')

# %%
doc = docx.Document()
table = doc.add_table(rows=1, cols=3)
table.style = 'Table Grid'
row = table.rows[0].cells
row[0].text = 'Input'
row[1].text = 'Output'
row[2].text = 'Time taken'

for i in x['data_5']:
    row = table.add_row().cells
    row[0].text = str((i['input']))
    row[1].text = str(i['output'])
    row[2].text = str(i['time'])

doc.save('output_5.docx')
